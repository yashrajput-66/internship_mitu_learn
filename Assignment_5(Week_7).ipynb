# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
"""
Download the seeds dataset from the below link and perform the following
operations.
https://archive.ics.uci.edu/ml/datasets/seeds
1. Read the dataset and seperate the input and output columns 2. Plot
the graph of class balancing
3. Perform train-test split with 80% and 20%
4. Create logistic regression model
5. Find accuracy, confusion matrix and classification report 6.
Perform the prediction of single value entry
""";

# %%
columns = [
    "Area",
    "Perimeter",
    "Compactness",
    "Kernel_Length",
    "Kernel_Width",
    "Asymmetry_Coefficient",
    "Kernel_Groove_Length",
    "Class"
]
df = pd.read_csv("seeds_dataset.txt", sep=r"\s+", header=None, names=columns)
df.to_csv("seeds_dataset.csv", index=False)

# %%
df
# Out:
#       Area  Perimeter  Compactness  Kernel_Length  Kernel_Width  \
# 0    15.26      14.84       0.8710          5.763         3.312
# 1    14.88      14.57       0.8811          5.554         3.333
# 2    14.29      14.09       0.9050          5.291         3.337
# 3    13.84      13.94       0.8955          5.324         3.379
# 4    16.14      14.99       0.9034          5.658         3.562
# ..     ...        ...          ...            ...           ...
# 205  12.19      13.20       0.8783          5.137         2.981
# 206  11.23      12.88       0.8511          5.140         2.795
# 207  13.20      13.66       0.8883          5.236         3.232
# 208  11.84      13.21       0.8521          5.175         2.836
# 209  12.30      13.34       0.8684          5.243         2.974
#
#      Asymmetry_Coefficient  Kernel_Groove_Length  Class
# 0                    2.221                 5.220      1
# 1                    1.018                 4.956      1
# 2                    2.699                 4.825      1
# 3                    2.259                 4.805      1
# 4                    1.355                 5.175      1
# ..                     ...                   ...    ...
# 205                  3.631                 4.870      3
# 206                  4.325                 5.003      3
# 207                  8.315                 5.056      3
# 208                  3.598                 5.044      3
# 209                  5.637                 5.063      3
#
# [210 rows x 8 columns]

# %%
X = df.drop("Class", axis = 1)

y = df['Class']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='Class', data=df)

plt.title("Class Balancing")
plt.xlabel("Class")
plt.ylabel("Count")
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, random_state = 0, test_size = 0.20)

# %%
x_train.shape, y_train.shape
# Out:
# ((168, 7), (168,))

# %%
X.describe()
# Out:
#              Area   Perimeter  Compactness  Kernel_Length  Kernel_Width  \
# count  210.000000  210.000000   210.000000     210.000000    210.000000
# mean    14.847524   14.559286     0.870999       5.628533      3.258605
# std      2.909699    1.305959     0.023629       0.443063      0.377714
# min     10.590000   12.410000     0.808100       4.899000      2.630000
# 25%     12.270000   13.450000     0.856900       5.262250      2.944000
# 50%     14.355000   14.320000     0.873450       5.523500      3.237000
# 75%     17.305000   15.715000     0.887775       5.979750      3.561750
# max     21.180000   17.250000     0.918300       6.675000      4.033000
#
#        Asymmetry_Coefficient  Kernel_Groove_Length
# count             210.000000            210.000000
# mean                3.700201              5.408071
# std                 1.503557              0.491480
# min                 0.765100              4.519000
# 25%                 2.561500              5.045000
# 50%                 3.599000              5.223000
# 75%                 4.768750              5.877000
# max                 8.456000              6.550000

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(max_iter = 1000)
model.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
y_pred = model.predict(x_test)

print("\nAccuracy:")
print(accuracy_score(y_test, y_pred))
# Out:
# Accuracy:
# 0.8809523809523809

# %%
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[12  1  0]
#  [ 4 12  0]
#  [ 0  0 13]]

# %%
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.75      0.92      0.83        13
#            2       0.92      0.75      0.83        16
#            3       1.00      1.00      1.00        13
#
#     accuracy                           0.88        42
#    macro avg       0.89      0.89      0.89        42
# weighted avg       0.89      0.88      0.88        42

# %%
sample = [[15.26, 14.84, 0.8710, 5.763, 3.312, 2.221, 5.220]]

prediction = model.predict(sample)

print("\nPredicted Class:", prediction[0])
# Out:
# Predicted Class: 1
# C:\Users\shrus\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
"""
Download the balance scale dataset from the below link and perform
following operations it.
https://archive.ics.uci.edu/ml/datasets/Balance+Scale
1. Read the dataset and seperate the input and output columns 2. Plot
the graph of class balancing
3. Perform train-test split with 75% and 25%
4. Create decision tree model
5. Find accuracy, confusion matrix and classification report 6.
Perform the prediction of single value entry.
7. Plot and save the tree.
""";

# %%
df = pd.read_csv("balance-scale.data", header = None)

# %%
df.columns = ["Class","Left_Weight","Left_Distance","Right_Weight","Right_Distance"]

# %%
df.head()
# Out:
#   Class  Left_Weight  Left_Distance  Right_Weight  Right_Distance
# 0     B            1              1             1               1
# 1     R            1              1             1               2
# 2     R            1              1             1               3
# 3     R            1              1             1               4
# 4     R            1              1             1               5

# %%
x = df.drop("Class", axis=1)
y = df["Class"]

# %%
plt.bar(y.value_counts().index, y.value_counts().values)
plt.xlabel("Class")
plt.ylabel("Count")
plt.title("Class Balancing")
# Out:
# Text(0.5, 1.0, 'Class Balancing')

# %%
x_train, x_test, y_train, y_test = train_test_split( x,y,test_size=0.25, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier(random_state=42)

# %%
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred = model.predict(x_test)

# %%
print("Accuracy =", accuracy_score(y_test, y_pred))
# Out:
# Accuracy = 0.7579617834394905

# %%
sample = [[1,1,1,1]]
result = model.predict(sample)

print("Predicted Class =", result)
# Out:
# Predicted Class = ['B']
# C:\Users\shrus\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize=(16,12))
plot_tree(
    model,
    feature_names=x.columns,
    class_names=model.classes_,
    filled=True
)
plt.title("Decision Tree")
# Out:
# Text(0.5, 1.0, 'Decision Tree')

# %%
"""
Download the balance scale dataset from the below link and perform
following operations it.
https://archive.ics.uci.edu/ml/datasets/Computer+Hardware 1. Read
the dataset and seperate the input and output columns 2. Perform
train-test split with 75% and 25%
3. Create decision tree model
4. Find Mean absolute error and accuracy
5. Perform the prediction of single value entry.
6. Plot and save the tree.
""";

# %%
df = pd.read_csv("machine.data", header=None)

# %%
df.columns = ["Vendor","Model","MYCT","MMIN","MMAX","CACH","CHMIN","CHMAX","PRP","ERP"]

# %%
df.head()
# Out:
#     Vendor    Model  MYCT  MMIN   MMAX  CACH  CHMIN  CHMAX  PRP  ERP
# 0  adviser    32/60   125   256   6000   256     16    128  198  199
# 1   amdahl   470v/7    29  8000  32000    32      8     32  269  253
# 2   amdahl  470v/7a    29  8000  32000    32      8     32  220  253
# 3   amdahl  470v/7b    29  8000  32000    32      8     32  172  253
# 4   amdahl  470v/7c    29  8000  16000    32      8     16  132  132

# %%
x = df[["MYCT","MMIN","MMAX","CACH","CHMIN","CHMAX"]]
y = df["PRP"]

# %%
x_train, x_test, y_train, y_test = train_test_split( x, y, test_size=0.25,random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()

# %%
model.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 67.9245283018868

# %%
from sklearn.metrics import r2_score

# %%
print("Accuracy =", r2_score(y_test, y_pred))
# Out:
# Accuracy = 0.5878817741667024

# %%
sample = [[125,256,6000,64,16,128]]

result = model.predict(sample)

print("Predicted PRP =", result)
# Out:
# Predicted PRP = [144.]
# C:\Users\shrus\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
plt.figure(figsize=(16,12))
plot_tree(
    model,
    feature_names=x.columns,
    filled=True
)

plt.title("Decision Tree")
# Out:
# Text(0.5, 1.0, 'Decision Tree')
